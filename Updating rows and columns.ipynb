# %%
import pandas as pd
import numpy as np

# %%
fruit = {'name':['mango','orange','apple'], 'price':[100, 80, 90], 'taste':['sweet','sour','bitter']}

# %%
df = pd.DataFrame(fruit)

# %%
df
# Out:
#      name  price   taste
# 0   mango    100   sweet
# 1  orange     80    sour
# 2   apple     90  bitter

# %%
df.columns
# Out:
# Index(['name', 'price', 'taste'], dtype='object')

# %%
df.columns = ['name of fruit', 'market_price','taste']

# %%
df
# Out:
#   name of fruit  market_price   taste
# 0         mango           100   sweet
# 1        orange            80    sour
# 2         apple            90  bitter

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#   NAME OF FRUIT  MARKET_PRICE   TASTE
# 0         mango           100   sweet
# 1        orange            80    sour
# 2         apple            90  bitter

# %%
df
# Out:
#   NAME OF FRUIT  MARKET_PRICE   TASTE
# 0         mango           100   sweet
# 1        orange            80    sour
# 2         apple            90  bitter

# %%
df.rename(columns={'NAME OF FRUIT':'FRUIT', 'MARKET_PRICE':'PRICE'},inplace = True)

# %%
df
# Out:
#     FRUIT  PRICE   TASTE
# 0   mango    100   sweet
# 1  orange     80    sour
# 2   apple     90  bitter

# %%
df.loc[1]
# Out:
# FRUIT    orange
# PRICE        80
# TASTE      sour
# Name: 1, dtype: object

# %%
df.loc[1,['FRUIT','PRICE']]
# Out:
# FRUIT    orange
# PRICE        80
# Name: 1, dtype: object

# %%
df.loc[1,'FRUIT']='limeta'

# %%
df
# Out:
#     FRUIT  PRICE   TASTE
# 0   mango    100   sweet
# 1  limeta     80    sour
# 2   apple     90  bitter

# %%
filt = df['FRUIT'] == 'mango'
df.loc[filt,'PRICE']= 120

# %%
df
# Out:
#     FRUIT  PRICE   TASTE
# 0   mango    120   sweet
# 1  limeta     80    sour
# 2   apple     90  bitter

# %%
df['FRUIT'].apply(len)
# Out:
# 0    5
# 1    6
# 2    5
# Name: FRUIT, dtype: int64

# %%
df.apply(len)
# Out:
# FRUIT    3
# PRICE    3
# TASTE    3
# dtype: int64

# %%
len(df)
# Out:
# 3

# %%
def Fruit(fruit):
    return fruit.upper()

# %%
df['TASTE'].apply(Fruit)
# Out:
# 0     SWEET
# 1      SOUR
# 2    BITTER
# Name: TASTE, dtype: object

# %%
df['TASTE'] = [x.upper() for x in df['TASTE']]

# %%
df
# Out:
#     FRUIT  PRICE   TASTE
# 0   mango    120   SWEET
# 1  limeta     80    SOUR
# 2   apple     90  BITTER

# %%
df['TASTE'] = df['TASTE'].apply(lambda x : x.lower())

# %%
df
# Out:
#     FRUIT  PRICE   TASTE
# 0   mango    120   sweet
# 1  limeta     80    sour
# 2   apple     90  bitter

# %%
df.apply(pd.Series.min)
# Out:
# FRUIT     apple
# PRICE        80
# TASTE    bitter
# dtype: object

# %%
df1 = df['FRUIT']

# %%
df1
# Out:
# 0     mango
# 1    limeta
# 2     apple
# Name: FRUIT, dtype: object

# %%
df.applymap(lambda x : len(str(x)))
# Out:
#    FRUIT  PRICE  TASTE
# 0      5      3      5
# 1      6      2      4
# 2      5      2      6

# %%
df.applymap(lambda x : str(x).upper())
# Out:
#     FRUIT PRICE   TASTE
# 0   MANGO   120   SWEET
# 1  LIMETA    80    SOUR
# 2   APPLE    90  BITTER

# %%
df
# Out:
#     FRUIT  PRICE   TASTE
# 0   mango    120   sweet
# 1  limeta     80    sour
# 2   apple     90  bitter

# %% [markdown]
# df['FRUIT'].map({'mango':'dragon_fruit})

# %%
df['FRUIT'].map({'mango':'draon fruit'})
# Out:
# 0    draon fruit
# 1            NaN
# 2            NaN
# Name: FRUIT, dtype: object

# %%
df['FRUIT'].replace({'mango':'draon fruit'})
# Out:
# 0    draon fruit
# 1         limeta
# 2          apple
# Name: FRUIT, dtype: object

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df["Hobbyist"]
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df["Hobbyist"] = df["Hobbyist"].map({'Yes': True, 'No': False})

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.rename(columns = {'Country':'Nation'},inplace = True)

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

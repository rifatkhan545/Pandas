# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Sales_Data/Sales_August_2019.csv')

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       236670            Wired Headphones                2      11.99
# 1       236671  Bose SoundSport Headphones                1      99.99
# 2       236672                      iPhone                1      700.0
# 3       236673       AA Batteries (4-pack)                2       3.84
# 4       236674       AA Batteries (4-pack)                2       3.84
# ...        ...                         ...              ...        ...
# 12006   248146  Bose SoundSport Headphones                1      99.99
# 12007   248147      AAA Batteries (4-pack)                3       2.99
# 12008   248148       AA Batteries (4-pack)                1       3.84
# 12009   248149        USB-C Charging Cable                1      11.95
# 12010   248150       AA Batteries (4-pack)                1       3.84
#
#            Order Date                         Purchase Address
# ...

# %%
files = [file for file in os.listdir('./Sales_Data')]

# %%
all_months_data = pd.DataFrame()
for file in files :
    df = pd.read_csv('./Sales_Data/'+file)
    all_months_data = pd.concat([df,all_months_data])
all_months_data.to_csv('complete_data.csv', index = False)
all_months_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   150502                    iPhone                1        700
# 1   150503     AA Batteries (4-pack)                1       3.84
# 2   150504    27in 4K Gaming Monitor                1     389.99
# 3   150505  Lightning Charging Cable                1      14.95
# 4   150506     AA Batteries (4-pack)                2       3.84
#
#        Order Date                     Purchase Address
# 0  02/18/19 01:35    866 Spruce St, Portland, ME 04101
# 1  02/13/19 07:24  18 13th St, San Francisco, CA 94016
# 2  02/18/19 09:46   52 6th St, New York City, NY 10001
# 3  02/02/19 16:47     129 Cherry St, Atlanta, GA 30301
# 4  02/28/19 20:32    548 Lincoln St, Seattle, WA 98101

# %%
all_months_data
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       150502                    iPhone                1        700
# 1       150503     AA Batteries (4-pack)                1       3.84
# 2       150504    27in 4K Gaming Monitor                1     389.99
# 3       150505  Lightning Charging Cable                1      14.95
# 4       150506     AA Batteries (4-pack)                2       3.84
# ...        ...                       ...              ...        ...
# 17656   295660    AAA Batteries (4-pack)                2       2.99
# 17657   295661      USB-C Charging Cable                1      11.95
# 17658   295662  Lightning Charging Cable                1      14.95
# 17659   295663    AAA Batteries (4-pack)                1       2.99
# 17660   295664              Google Phone                1        600
#
#            Order Date                     Purchase Address
# 0      02/18/19 01:35    866 Spruce St, Portland, ME 04101
# ...

# %%
df1= pd.read_csv('complete_data.csv')

# %%
df1
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        150502                    iPhone                1        700
# 1        150503     AA Batteries (4-pack)                1       3.84
# 2        150504    27in 4K Gaming Monitor                1     389.99
# 3        150505  Lightning Charging Cable                1      14.95
# 4        150506     AA Batteries (4-pack)                2       3.84
# ...         ...                       ...              ...        ...
# 186845   295660    AAA Batteries (4-pack)                2       2.99
# 186846   295661      USB-C Charging Cable                1      11.95
# 186847   295662  Lightning Charging Cable                1      14.95
# 186848   295663    AAA Batteries (4-pack)                1       2.99
# 186849   295664              Google Phone                1        600
#
#             Order Date                     Purchase Address
# 0       02/18/19 01:35    866 Spruce St, Portland, ME 04101
# ...

# %%
df1['month']=df1['Order Date'].str[0:2]

# %%
df1 = df1.dropna(how ='all')

# %%
df2 = df1[df1['Order Date'].str[0:2]!= 'Or']

# %%
df2['month']= df2['Order Date'].str[0:2]
# Out:
# <ipython-input-13-57445fa506ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['month']= df2['Order Date'].str[0:2]

# %%
df2['month']=df2['month'].astype('int32')
# Out:
# <ipython-input-14-6444b579a268>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['month']=df2['month'].astype('int32')

# %%
df2['month']=df2['month'].astype('int32')
# Out:
# <ipython-input-15-6444b579a268>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['month']=df2['month'].astype('int32')

# %%
type(df2['month'])
# Out:
# pandas.core.series.Series

# %%
df2['month']*3
# Out:
# 0          6
# 1          6
# 2          6
# 3          6
# 4          6
#           ..
# 186845    33
# 186846    33
# 186847    33
# 186848    33
# 186849    33
# Name: month, Length: 185950, dtype: int32

# %%
df2['Quantity Ordered'] = pd.to_numeric(df2['Quantity Ordered'])
df2['Price Each'] = pd.to_numeric(df2['Price Each'])
df2['total sale'] = df2['Quantity Ordered']*df2['Price Each']
# Out:
# <ipython-input-18-75ba341658db>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Quantity Ordered'] = pd.to_numeric(df2['Quantity Ordered'])
# <ipython-input-18-75ba341658db>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Price Each'] = pd.to_numeric(df2['Price Each'])
# <ipython-input-18-75ba341658db>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df2
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        150502                    iPhone                 1      700.00
# 1        150503     AA Batteries (4-pack)                 1        3.84
# 2        150504    27in 4K Gaming Monitor                 1      389.99
# 3        150505  Lightning Charging Cable                 1       14.95
# 4        150506     AA Batteries (4-pack)                 2        3.84
# ...         ...                       ...               ...         ...
# 186845   295660    AAA Batteries (4-pack)                 2        2.99
# 186846   295661      USB-C Charging Cable                 1       11.95
# 186847   295662  Lightning Charging Cable                 1       14.95
# 186848   295663    AAA Batteries (4-pack)                 1        2.99
# 186849   295664              Google Phone                 1      600.00
#
#             Order Date                     Purchase Address  month  total sale
# ...

# %%
month_wise_sale = df2.groupby('month').sum()

# %%
month_wise_sale.max()
# Out:
# Quantity Ordered    2.811400e+04
# Price Each          4.588415e+06
# total sale          4.613443e+06
# dtype: float64

# %%
month_wise_sale.min()
# Out:
# Quantity Ordered      10903.00
# Price Each          1811768.38
# total sale          1822256.73
# dtype: float64

# %%
month_wise_sale
# Out:
#        Quantity Ordered    Price Each    total sale
# month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
months = range(1,13)
plt.bar(months, month_wise_sale['total sale'])
plt.xticks(months)
plt.ylabel('sales in usd')
plt.xlabel('months')
plt.show()

# %%
df2['city'] = df2['Purchase Address'].apply(lambda x : x.split(',')[1]+','+x.split(',')[2].split(' ')[1])
# Out:
# <ipython-input-25-aa6cc7a4ac8f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['city'] = df2['Purchase Address'].apply(lambda x : x.split(',')[1]+','+x.split(',')[2].split(' ')[1])

# %%
df2
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        150502                    iPhone                 1      700.00
# 1        150503     AA Batteries (4-pack)                 1        3.84
# 2        150504    27in 4K Gaming Monitor                 1      389.99
# 3        150505  Lightning Charging Cable                 1       14.95
# 4        150506     AA Batteries (4-pack)                 2        3.84
# ...         ...                       ...               ...         ...
# 186845   295660    AAA Batteries (4-pack)                 2        2.99
# 186846   295661      USB-C Charging Cable                 1       11.95
# 186847   295662  Lightning Charging Cable                 1       14.95
# 186848   295663    AAA Batteries (4-pack)                 1        2.99
# 186849   295664              Google Phone                 1      600.00
#
#             Order Date                     Purchase Address  month  \
# ...

# %%
result=df2.groupby('city').sum()

# %%
result
# Out:
#                    Quantity Ordered    Price Each   month    total sale
# city
#  Atlanta,GA                   16602  2.779908e+06  104794  2.795499e+06
#  Austin,TX                    11153  1.809874e+06   69829  1.819582e+06
#  Boston,MA                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas,TX                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles,CA               33289  5.421435e+06  208325  5.452571e+06
#  New York City,NY             27932  4.635371e+06  175741  4.664317e+06
#  Portland,ME                   2750  4.471893e+05   17144  4.497583e+05
#  Portland,OR                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco,CA             50239  8.211462e+06  315520  8.262204e+06
#  Seattle,WA                   16553  2.733296e+06  104941  2.747755e+06

# %%
city = [city for city, df in df2.groupby('city')]
plt.bar(city, result['total sale'])
plt.xticks(city, rotation = 'vertical')
plt.ylabel('sales in usd')
plt.xlabel('city')
plt.show()

# %%
df2
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        150502                    iPhone                 1      700.00
# 1        150503     AA Batteries (4-pack)                 1        3.84
# 2        150504    27in 4K Gaming Monitor                 1      389.99
# 3        150505  Lightning Charging Cable                 1       14.95
# 4        150506     AA Batteries (4-pack)                 2        3.84
# ...         ...                       ...               ...         ...
# 186845   295660    AAA Batteries (4-pack)                 2        2.99
# 186846   295661      USB-C Charging Cable                 1       11.95
# 186847   295662  Lightning Charging Cable                 1       14.95
# 186848   295663    AAA Batteries (4-pack)                 1        2.99
# 186849   295664              Google Phone                 1      600.00
#
#             Order Date                     Purchase Address  month  \
# ...

# %%
df2['Order Date']= pd.to_datetime(df2['Order Date'])
# Out:
# <ipython-input-31-d2f4c03bcfcb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Order Date']= pd.to_datetime(df2['Order Date'])

# %%
df2
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        150502                    iPhone                 1      700.00
# 1        150503     AA Batteries (4-pack)                 1        3.84
# 2        150504    27in 4K Gaming Monitor                 1      389.99
# 3        150505  Lightning Charging Cable                 1       14.95
# 4        150506     AA Batteries (4-pack)                 2        3.84
# ...         ...                       ...               ...         ...
# 186845   295660    AAA Batteries (4-pack)                 2        2.99
# 186846   295661      USB-C Charging Cable                 1       11.95
# 186847   295662  Lightning Charging Cable                 1       14.95
# 186848   295663    AAA Batteries (4-pack)                 1        2.99
# 186849   295664              Google Phone                 1      600.00
#
#                 Order Date                     Purchase Address  month  \
# ...

# %%
df2['hour'] = df2['Order Date'].dt.hour
# Out:
# <ipython-input-33-35bc64cd125c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['hour'] = df2['Order Date'].dt.hour

# %%
df2
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        150502                    iPhone                 1      700.00
# 1        150503     AA Batteries (4-pack)                 1        3.84
# 2        150504    27in 4K Gaming Monitor                 1      389.99
# 3        150505  Lightning Charging Cable                 1       14.95
# 4        150506     AA Batteries (4-pack)                 2        3.84
# ...         ...                       ...               ...         ...
# 186845   295660    AAA Batteries (4-pack)                 2        2.99
# 186846   295661      USB-C Charging Cable                 1       11.95
# 186847   295662  Lightning Charging Cable                 1       14.95
# 186848   295663    AAA Batteries (4-pack)                 1        2.99
# 186849   295664              Google Phone                 1      600.00
#
#                 Order Date                     Purchase Address  month  \
# ...

# %%
result_hour = df2.groupby('hour').count()

# %%
result_hour
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
hour = [hour for hour, df in df2.groupby('hour')]
plt.xticks(hour, rotation = 'vertical')
plt.xlabel('hour')
plt.ylabel('sales in usd')
plt.plot(hour, result_hour)
plt.grid()
plt.show()

# %%
# what products are often sold together

# %%
df2
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        150502                    iPhone                 1      700.00
# 1        150503     AA Batteries (4-pack)                 1        3.84
# 2        150504    27in 4K Gaming Monitor                 1      389.99
# 3        150505  Lightning Charging Cable                 1       14.95
# 4        150506     AA Batteries (4-pack)                 2        3.84
# ...         ...                       ...               ...         ...
# 186845   295660    AAA Batteries (4-pack)                 2        2.99
# 186846   295661      USB-C Charging Cable                 1       11.95
# 186847   295662  Lightning Charging Cable                 1       14.95
# 186848   295663    AAA Batteries (4-pack)                 1        2.99
# 186849   295664              Google Phone                 1      600.00
#
#                 Order Date                     Purchase Address  month  \
# ...

# %%
df= df2[df2['Order ID'].duplicated(keep=False)]
df['grouped'] = df.groupby('Order ID')['Product'].transform(lambda x : ', '. join(x))
df3 = df[['Order ID', 'grouped']].drop_duplicates()
# Out:
# <ipython-input-40-e15e9dd35119>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['grouped'] = df.groupby('Order ID')['Product'].transform(lambda x : ', '. join(x))

# %% [markdown]
# ###

# %%
df3
# Out:
#        Order ID                                           grouped
# 16       150518                        Macbook Pro Laptop, iPhone
# 82       150582                  iPhone, Lightning Charging Cable
# 91       150590  Apple Airpods Headphones, AAA Batteries (4-pack)
# 119      150617                Google Phone, USB-C Charging Cable
# 154      150651                Google Phone, USB-C Charging Cable
# ...         ...                                               ...
# 186667   295487      Apple Airpods Headphones, Macbook Pro Laptop
# 186694   295513                  iPhone, Lightning Charging Cable
# 186708   295526        Apple Airpods Headphones, 27in FHD Monitor
# 186717   295534                Google Phone, USB-C Charging Cable
# 186783   295599                  iPhone, Apple Airpods Headphones
#
# [7136 rows x 2 columns]

# %%
df3
# Out:
#        Order ID                                           grouped
# 16       150518                        Macbook Pro Laptop, iPhone
# 82       150582                  iPhone, Lightning Charging Cable
# 91       150590  Apple Airpods Headphones, AAA Batteries (4-pack)
# 119      150617                Google Phone, USB-C Charging Cable
# 154      150651                Google Phone, USB-C Charging Cable
# ...         ...                                               ...
# 186667   295487      Apple Airpods Headphones, Macbook Pro Laptop
# 186694   295513                  iPhone, Lightning Charging Cable
# 186708   295526        Apple Airpods Headphones, 27in FHD Monitor
# 186717   295534                Google Phone, USB-C Charging Cable
# 186783   295599                  iPhone, Apple Airpods Headphones
#
# [7136 rows x 2 columns]

# %%
# Referenced: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary
from itertools import combinations
from collections import Counter

count = Counter()
for x in df3['grouped']:
    y = x.split(',')
    count.update(Counter(combinations(y, 2)))

# %%
print(count)
# Out:
# Counter({('iPhone', ' Lightning Charging Cable'): 1005, ('Google Phone', ' USB-C Charging Cable'): 987, ('iPhone', ' Wired Headphones'): 447, ('Google Phone', ' Wired Headphones'): 414, ('Vareebadd Phone', ' USB-C Charging Cable'): 361, ('iPhone', ' Apple Airpods Headphones'): 360, ('Google Phone', ' Bose SoundSport Headphones'): 220, ('Vareebadd Phone', ' Wired Headphones'): 143, (' USB-C Charging Cable', ' Wired Headphones'): 120, ('Vareebadd Phone', ' Bose SoundSport Headphones'): 80, (' Lightning Charging Cable', ' Wired Headphones'): 62, ('Lightning Charging Cable', ' USB-C Charging Cable'): 55, ('Lightning Charging Cable', ' AA Batteries (4-pack)'): 52, ('Lightning Charging Cable', ' Lightning Charging Cable'): 51, (' USB-C Charging Cable', ' Bose SoundSport Headphones'): 51, ('AA Batteries (4-pack)', ' Lightning Charging Cable'): 51, ('AAA Batteries (4-pack)', ' USB-C Charging Cable'): 50, ('AAA Batteries (4-pack)', ' AAA Batteries (4-pack)'): 48, ('AA Batteries (4-pack)', ' A
# ...

# %%
count.most_common(10)
# Out:
# [(('iPhone', ' Lightning Charging Cable'), 1005),
#  (('Google Phone', ' USB-C Charging Cable'), 987),
#  (('iPhone', ' Wired Headphones'), 447),
#  (('Google Phone', ' Wired Headphones'), 414),
#  (('Vareebadd Phone', ' USB-C Charging Cable'), 361),
#  (('iPhone', ' Apple Airpods Headphones'), 360),
#  (('Google Phone', ' Bose SoundSport Headphones'), 220),
#  (('Vareebadd Phone', ' Wired Headphones'), 143),
#  ((' USB-C Charging Cable', ' Wired Headphones'), 120),
#  (('Vareebadd Phone', ' Bose SoundSport Headphones'), 80)]

# %%
for (key,value) in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', ' Lightning Charging Cable') 1005
# ('Google Phone', ' USB-C Charging Cable') 987
# ('iPhone', ' Wired Headphones') 447
# ('Google Phone', ' Wired Headphones') 414
# ('Vareebadd Phone', ' USB-C Charging Cable') 361
# ('iPhone', ' Apple Airpods Headphones') 360
# ('Google Phone', ' Bose SoundSport Headphones') 220
# ('Vareebadd Phone', ' Wired Headphones') 143
# (' USB-C Charging Cable', ' Wired Headphones') 120
# ('Vareebadd Phone', ' Bose SoundSport Headphones') 80

# %%
df2
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        150502                    iPhone                 1      700.00
# 1        150503     AA Batteries (4-pack)                 1        3.84
# 2        150504    27in 4K Gaming Monitor                 1      389.99
# 3        150505  Lightning Charging Cable                 1       14.95
# 4        150506     AA Batteries (4-pack)                 2        3.84
# ...         ...                       ...               ...         ...
# 186845   295660    AAA Batteries (4-pack)                 2        2.99
# 186846   295661      USB-C Charging Cable                 1       11.95
# 186847   295662  Lightning Charging Cable                 1       14.95
# 186848   295663    AAA Batteries (4-pack)                 1        2.99
# 186849   295664              Google Phone                 1      600.00
#
#                 Order Date                     Purchase Address  month  \
# ...

# %%
product_group = df2.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']
quantity_ordered
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %%
keys = [pair for pair, df in product_group]
plt.bar(keys, quantity_ordered)
plt.xticks(keys, rotation='vertical')
plt.show()

# %%
prices = df2.groupby('Product').mean()['Price Each']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(keys, quantity_ordered, color='g')
ax2.plot(keys, prices, color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(keys, rotation='vertical', size=8)

fig.show()
# Out:
# <ipython-input-58-5be80f7b33d1>:14: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

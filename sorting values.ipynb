# %%
people = {'first' : ['rifat', 'anik', 'samsu', 'khal'], 'last' : ['khan', 'hal', 'pop','pop'], 'age': [20, 22, 32,35]}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first  last  age
# 0  rifat  khan   20
# 1   anik   hal   22
# 2  samsu   pop   32
# 3   khal   pop   35

# %%
df.sort_values(by=['last', 'first'],ascending= [False, True])
# Out:
#    first  last  age
# 3   khal   pop   35
# 2  samsu   pop   32
# 0  rifat  khan   20
# 1   anik   hal   22

# %%
df.sort_index()
# Out:
#    first  last  age
# 0  rifat  khan   20
# 1   anik   hal   22
# 2  samsu   pop   32

# %%
df['last'].sort_values()
# Out:
# 1     hal
# 0    khan
# 2     pop
# 3     pop
# Name: last, dtype: object

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.sort_values(by ='Country', ascending = False)
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 60693       61083  I am a student who is learning to code      Yes
# 47789       48100             I code primarily as a hobby      Yes
# 6466         6492          I am a developer by profession      Yes
# 66038       66459          I am a developer by profession      Yes
# 6460         6486  I am a student who is learning to code      Yes
# ...           ...                                     ...      ...
# 88873       88062                                     NaN       No
# 88874       88076                                     NaN       No
# 88879       88601                                     NaN       No
# 88880       88802                                     NaN       No
# 88881       88816                                     NaN       No
#
#                                              OpenSourcer  \
# 60693                                              Never
# ...

# %%
df[['Country','Age','ConvertedComp']].head(50)
# Out:
#            Country   Age  ConvertedComp
# 39018  Afghanistan  26.0        19152.0
# 86551  Afghanistan   NaN            NaN
# 58390  Afghanistan   NaN            NaN
# 73920  Afghanistan  23.0            NaN
# 28877  Afghanistan   NaN            NaN
# 51525  Afghanistan   NaN            NaN
# 45562  Afghanistan  85.0            NaN
# 46807  Afghanistan  21.0            NaN
# 44123  Afghanistan  25.0            NaN
# 22327  Afghanistan  24.0         7980.0
# 8112   Afghanistan  24.0         1596.0
# 80423  Afghanistan  18.0            NaN
# 59184  Afghanistan   NaN            NaN
# 60185  Afghanistan  23.0            NaN
# 37571  Afghanistan   NaN            NaN
# 29560  Afghanistan  26.0         1116.0
# 42832  Afghanistan   NaN            NaN
# 12253  Afghanistan   NaN            NaN
# 58082  Afghanistan  26.0        17556.0
# 50172  Afghanistan  34.0       153216.0
# 7323   Afghanistan   NaN            NaN
# 7056   Afghanistan  26.0        14364.0
# ...

# %%
df.sort_values(by = ['Country','ConvertedComp'],ascending=[True, False], inplace = True)

# %%
df[['Country','ConvertedComp']]
# Out:
#            Country  ConvertedComp
# 62723  Afghanistan      1000000.0
# 50172  Afghanistan       153216.0
# 39018  Afghanistan        19152.0
# 58082  Afghanistan        17556.0
# 7056   Afghanistan        14364.0
# ...            ...            ...
# 88873          NaN            NaN
# 88874          NaN            NaN
# 88879          NaN            NaN
# 88880          NaN            NaN
# 88881          NaN            NaN
#
# [88883 rows x 2 columns]

# %%
df['ConvertedComp'].nlargest(20)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 21895    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# 83866    2000000.0
# 50196    2000000.0
# 50200    2000000.0
# 58134    2000000.0
# 58147    2000000.0
# 58118    2000000.0
# 58307    2000000.0
# 49819    2000000.0
# 59892    2000000.0
# 47557    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 25833       25983                     I am a developer by profession      Yes
# 87353       87896                     I am a developer by profession      Yes
# 28080       28243                     I am a developer by profession      Yes
# 72274       72732  I am not primarily a developer, but I write co...       No
# 21895       22013                     I am a developer by profession      Yes
# 77665       78151                     I am a developer by profession      Yes
# 79701       80200                     I am a developer by profession      Yes
# 51798       52132                     I am a developer by profession      Yes
# 75088       75561                     I am a developer by profession      Yes
# 32056       32250                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...
